# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# !pip install atari_py

# %%
from google.colab import drive

drive.mount('/content/drive', force_remount = True)

# %%
# !python -m atari_py.import_roms '/content/drive/My Drive/CN_Breakout/ROMS'

# %%
#!/usr/bin/env python


#https://becominghuman.ai/lets-build-an-atari-ai-part-1-dqn-df57e8ff3b26
from __future__ import print_function

import argparse
import skimage as skimage
from skimage import transform, color, exposure
from skimage.transform import rotate
from skimage.viewer import ImageViewer
import random
import numpy as np
from collections import deque

import json
from tensorflow.keras.initializers import identity
from tensorflow.keras.models import model_from_json
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD , Adam
import tensorflow as tf
#import agent
# Import the gym module
import gym

from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay

from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()


GAME = 'atari' # the name of the game being played for log files
CONFIG = 'nothreshold'
ACTIONS = 3 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVATION = 200. # timesteps to observe before training. de cada 3200 frames, vamos ao nosso buffer e selecionamos de forma aleatoria um batch size. Neste caso, 32 frames. em numpy arrays
EXPLORE = 3000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.01 # starting value of epsilon EPSILON é para ver o exploration vs exploitation
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
#MAX_STEPS_PER_EPISODE = 1000
EPISODES = 10000
q_max_list = []
loss_list = []
reward_list = []

img_rows, img_cols = 84, 84
#Convert image into Black and white
img_channels = 4 #We stack 4 frames

def buildmodel():
    # Network defined by the Deepmind paper
    inputs = tf.keras.layers.Input(shape=(84, 84, 4,))

    # Convolutions on the frames on the screen
    layer1 = Conv2D(32, 8, strides=4, activation="relu", padding = 'same')(inputs)
    drop1 =  Dropout(0.5)(layer1)
    layer2 = Conv2D(64, 4, strides=2, activation="relu", padding = 'same')(drop1)
    drop2 =  Dropout(0.5)(layer2)
    layer3 = Conv2D(64, 3, strides=1, activation="relu", padding = 'same')(drop2)
    layer4 = Conv2D(1024, 7, strides=1, activation="relu", padding = 'same')(layer3)

    layer5 = Flatten()(layer4)

    layer6 = Dense(512, activation="relu")(layer5)
    action = Dense(ACTIONS, activation="linear")(layer6)

    return tf.keras.Model(inputs=inputs, outputs=action)

def buildmodel2():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(filters = 32, kernel_size = (8, 8), strides = (4, 4), padding = 'same', input_shape = (img_rows, img_cols, img_channels)))  #80*80*4
    model.add(Activation('relu'))
    model.add(Conv2D(filters = 64, kernel_size = (4, 4), strides = (2, 2), padding = 'same'))
    model.add(Activation('relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3, 3), strides = (1, 1), padding = 'same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))

    adam = Adam(learning_rate = LEARNING_RATE)
    model.compile(loss='mse', optimizer = adam)
    print("We finish building the model")
    return model


def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env


def trainNetwork(model,args):
    # open up a game state to communicate with emulator
    env = wrap_env(gym.make('BreakoutDeterministic-v4'))
    env.reset()
    # store the previous observations in replay memory
    
    #----------------------------------------
    #PARA OBTER O SIGNIFICADO DAS AÇÕES POSSíVEIS
    #print(env.unwrapped.get_action_meanings())
    #----------------------------------------
    
    # get the first state by doing nothing and preprocess the image to 80x80x4
        
    x_t, r_0, terminal, info = env.step(1) #COMEÇAR O JOGO COM A AÇÃO "FIRE"
    
    env.render()

    D = args['D']

    x_t = skimage.color.rgb2gray(x_t)
    x_t = skimage.transform.resize(x_t, (84,84))
    x_t = skimage.exposure.rescale_intensity(x_t, out_range = (0,255))

    x_t = x_t / 255.0

    s_t = np.stack((x_t, x_t, x_t, x_t), axis = 2) #colocar a sequência de frames. 4 frames sequenciais, que vamos aplicar à nossa lista. Para conseguir a estabilidade de imagens sequenciais
    
    #print (s_t.shape)

    #In Keras, need to reshape
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*80*80*4

    t = args['t']

    if args['mode'] == 'Run':
        OBSERVE = 999999999	#We keep observe, never train
        epsilon = FINAL_EPSILON # higher epsilon, more timestamps?
        print ("Now we load weight")
        model.load_weights("/content/drive/My Drive/CN_Breakout/models/model_v1.h5")
        adam = Adam(learning_rate = LEARNING_RATE)
        model.compile(loss = 'mse', optimizer = adam)
        print ("Weight load successfully")

    elif args['mode'] == 'CTrain': #Continue previous train
        OBSERVE = OBSERVATION
        #epsilon = 0.07823368810419994 #0.08811709480229288
        epsilon = args['epsilon']
        print ("Now we load weight")
        model.load_weights("/content/drive/My Drive/CN_Breakout/models/model.h5")
        adam = Adam(learning_rate = LEARNING_RATE)
        model.compile(loss = 'mse', optimizer = adam)
        print ("Weight load successfully")
        

    else:					   #We go to training mode -> -m "Train"
        OBSERVE = OBSERVATION
        #epsilon = INITIAL_EPSILON #o EPSILON é o que divide a parte de exploration vs exploitation. se for abaixo de um dado valor é exploration. Caso contrário é exploitation
        epsilon = args['epsilon']
        adam = Adam(learning_rate = LEARNING_RATE)
        model.compile(loss = 'mse', optimizer = adam)

    lives = 5
    r_total = 0
    while (lives > 0):
    #for i in range(MAX_STEPS_PER_EPISODE):
        loss = 0
        Q_sa = 0 # Q(s, a) representing the maximum discounted future reward when we perform action a in state s.
        action_index = 0
        r_t = 0 #reward
        a_t = np.zeros([ACTIONS]) #action
      
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0:
            if random.random() <= epsilon:
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
                
            else:
                q = model.predict(s_t)	   #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)
               # print(max_Q, q, a_t)
                action_index = max_Q
                a_t[max_Q] = 1

        #We reduce the epsilon gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        #run the selected action and observed next state and reward. DEPOIS DE UM "STEP" correr sempre o "RENDER"
        x_t1_colored, r_t, terminal, info = env.step(list(a_t).index(1) + 1) #FUNÇÂO "WHERE" para obter o índice do valor do array que está a 1
        print("INFO", info)
        print("Terminal", terminal)
        if info['ale.lives'] < lives:
          lives -= 1
          r_t = -1.0
          if info['ale.lives'] > 0:
            env.step(1)
        env.render()
        
        x_t1 = skimage.color.rgb2gray(x_t1_colored)
        x_t1 = skimage.transform.resize(x_t1, (84, 84))
        x_t1 = skimage.exposure.rescale_intensity(x_t1, out_range = (0, 255))
        
        x_t1 = x_t1 / 255.0


        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x80x80x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis = 3)

        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: #train ou update da nossa rede. de quantas em quantas frames vamos precisar para fazer um treino. se replay_mem começar a ficar mto cheio retira a última entrada. e fazemos append das novas decisoes que foram sendo adquiridas
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)

            #Now we do the experience replay
            state_t, action_t, reward_t, state_t1, terminal = zip(*minibatch)
            state_t = np.concatenate(state_t)
            state_t1 = np.concatenate(state_t1)
            targets = model.predict(state_t)
            Q_sa = model.predict(state_t1)
            #r_total += reward_t
            targets[range(BATCH), action_t] = reward_t + GAMMA * np.max(Q_sa, axis = 1) * np.invert(terminal) #qual o target associado
            
            
            loss += model.train_on_batch(state_t, targets) #quanto mais proximo de zero, mais proximo está de convergir para conseguir estimar o key value de acordo com o par (estado, ação)
            
        s_t = s_t1
        t = t + 1

        # save progress every 1000 iterations
        if t % 100 == 0:
            print("Now we save model")
            model.save_weights("/content/drive/My Drive/CN_Breakout/models/model.h5", overwrite = True)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"


        print("TIMESTEP", t, "/ STATE", state, \
            "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, \
            "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)
        
        q_max_list.append(np.max(Q_sa))
        loss_list.append(loss)
        reward_list.append(r_t)

    env.close()
    print("Episode finished!")
    print("************************")
    return t, epsilon, D

def playGame(args):
    model = buildmodel()
    t, epsilon, D = trainNetwork(model,args)
    return t, epsilon, D

def main():
    #parser = argparse.ArgumentParser(description = 'Description of your program')
    #parser.add_argument('-m','--mode', help = 'Train / CTrain / Run', required=True)
    #parser.add_argument('-m','--mode', help = 'Train / CTrain / Run', required=True) adicionar o argumento de número de episódios
    #args = vars(parser.parse_args())
    t = 0
    epsilon = INITIAL_EPSILON
    D = deque()
    for i in range(EPISODES):
        print("EPISODE", i)
        tp, epsilonp, Dp = playGame({'mode': 'Train', 't': t, 'epsilon': epsilon, 'D': D})
        #show_video()
        t = tp
        epsilon = epsilonp
        D = Dp

if __name__ == "__main__":
    main()
# Out:
# EPISODE 0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 1 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 2 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 3 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 4 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 5 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 6 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 7 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 8 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 9 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 10 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 11 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 12 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 13 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 14 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 15 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 16 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 17 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 18 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 19 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 20 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 21 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 22 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 23 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 24 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD -1.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 25 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 26 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 27 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 28 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 29 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 30 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 31 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 32 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 33 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 34 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 35 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 36 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 37 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 38 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 39 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 40 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 41 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 42 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 43 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 44 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 45 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 46 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 47 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD -1.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 48 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 49 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 50 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 51 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 52 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 53 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 54 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 55 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 56 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 57 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 58 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 59 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 60 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 61 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 62 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 63 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 64 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 65 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 66 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 67 / STATE observe / EPSILON 0.01 / ACTION 2 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 68 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 69 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 70 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD -1.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 71 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 72 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 73 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 74 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 75 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 76 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 77 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 78 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 79 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 80 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 81 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 82 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 83 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 84 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 85 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 86 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 87 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 88 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 89 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 90 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 91 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 92 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 93 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 94 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 95 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 96 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 97 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 98 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 99 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# Now we save model
# TIMESTEP 100 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 101 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 1.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 102 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 103 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 104 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 105 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 106 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 107 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 108 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 109 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 110 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 111 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 112 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 113 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 114 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 115 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 116 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 117 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 118 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 119 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 120 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 121 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 122 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD -1.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 123 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 124 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 125 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 126 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 127 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 128 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 129 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 130 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 131 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 132 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 133 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 134 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 135 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 136 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 137 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 138 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 139 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 140 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 141 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 142 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 143 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 144 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 145 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 146 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 147 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 148 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 149 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 150 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 151 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 152 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 153 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 1.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 154 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 155 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 156 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 157 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 158 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 159 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 160 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 161 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 162 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 163 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 164 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 165 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 166 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 167 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 168 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 169 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 170 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 171 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 172 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 173 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 0}
# Terminal True
# TIMESTEP 174 / STATE observe / EPSILON 0.01 / ACTION 0 / REWARD -1.0 / Q_MAX  0 / Loss  0
# Episode finished!
# ************************
# EPISODE 1
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 175 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 176 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 177 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 178 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 179 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 180 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 181 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 182 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 183 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 184 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 185 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 186 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 187 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 188 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 189 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 190 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 191 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 192 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 193 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 194 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 195 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 196 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 5}
# Terminal False
# TIMESTEP 197 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 198 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD -1.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 199 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# Now we save model
# TIMESTEP 200 / STATE observe / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 201 / STATE explore / EPSILON 0.01 / ACTION 1 / REWARD 0.0 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 202 / STATE explore / EPSILON 0.0099967 / ACTION 1 / REWARD 0.0 / Q_MAX  0.002447554 / Loss  0.03220483660697937
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 203 / STATE explore / EPSILON 0.009993400000000001 / ACTION 2 / REWARD 0.0 / Q_MAX  -0.13445969 / Loss  0.3740524649620056
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 204 / STATE explore / EPSILON 0.009990100000000002 / ACTION 0 / REWARD 0.0 / Q_MAX  -0.052393995 / Loss  0.02397138439118862
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 205 / STATE explore / EPSILON 0.009986800000000002 / ACTION 0 / REWARD 0.0 / Q_MAX  0.057455916 / Loss  0.0172378309071064
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 206 / STATE explore / EPSILON 0.009983500000000003 / ACTION 0 / REWARD 0.0 / Q_MAX  0.046757642 / Loss  0.01956021599471569
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 207 / STATE explore / EPSILON 0.009980200000000003 / ACTION 0 / REWARD 0.0 / Q_MAX  0.03220522 / Loss  0.02142413705587387
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 208 / STATE explore / EPSILON 0.009976900000000004 / ACTION 0 / REWARD 0.0 / Q_MAX  0.021362841 / Loss  0.01142896804958582
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 209 / STATE explore / EPSILON 0.009973600000000004 / ACTION 0 / REWARD 0.0 / Q_MAX  0.01436575 / Loss  0.020976129919290543
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 210 / STATE explore / EPSILON 0.009970300000000005 / ACTION 1 / REWARD 0.0 / Q_MAX  0.0154933445 / Loss  0.010789095424115658
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 211 / STATE explore / EPSILON 0.009967000000000005 / ACTION 1 / REWARD 0.0 / Q_MAX  0.017311953 / Loss  0.010668927803635597
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 212 / STATE explore / EPSILON 0.009963700000000006 / ACTION 1 / REWARD 0.0 / Q_MAX  0.01781132 / Loss  0.00014567028847523034
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 213 / STATE explore / EPSILON 0.009960400000000006 / ACTION 1 / REWARD 0.0 / Q_MAX  0.01763742 / Loss  0.041444458067417145
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 214 / STATE explore / EPSILON 0.009957100000000007 / ACTION 1 / REWARD 0.0 / Q_MAX  0.017277738 / Loss  0.010399041697382927
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 215 / STATE explore / EPSILON 0.009953800000000007 / ACTION 1 / REWARD 0.0 / Q_MAX  0.01695505 / Loss  0.010317390784621239
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 216 / STATE explore / EPSILON 0.009950500000000008 / ACTION 1 / REWARD 0.0 / Q_MAX  0.016279364 / Loss  0.010878278873860836
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 217 / STATE explore / EPSILON 0.009947200000000008 / ACTION 1 / REWARD 0.0 / Q_MAX  0.015224477 / Loss  0.020994052290916443
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 218 / STATE explore / EPSILON 0.009943900000000009 / ACTION 1 / REWARD 0.0 / Q_MAX  0.014286425 / Loss  0.01028279960155487
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 219 / STATE explore / EPSILON 0.00994060000000001 / ACTION 1 / REWARD 0.0 / Q_MAX  0.013271208 / Loss  0.021023305132985115
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 220 / STATE explore / EPSILON 0.00993730000000001 / ACTION 1 / REWARD 0.0 / Q_MAX  0.0123677375 / Loss  0.0001239617558894679
# INFO {'ale.lives': 4}
# Terminal False
# TIMESTEP 221 / STATE explore / EPSILON 0.00993400000000001 / ACTION 1 / REWARD 0.0 / Q_MAX  0.011504059 / Loss  9.81361954472959e-05
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 222 / STATE explore / EPSILON 0.009930700000000011 / ACTION 1 / REWARD -1.0 / Q_MAX  0.010681888 / Loss  0.010717611759901047
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 223 / STATE explore / EPSILON 0.009927400000000012 / ACTION 1 / REWARD 0.0 / Q_MAX  0.009780931 / Loss  0.0107254134491086
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 224 / STATE explore / EPSILON 0.009924100000000012 / ACTION 1 / REWARD 0.0 / Q_MAX  0.008856371 / Loss  0.020740553736686707
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 225 / STATE explore / EPSILON 0.009920800000000013 / ACTION 1 / REWARD 0.0 / Q_MAX  0.008094118 / Loss  0.03129054605960846
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 1444 / STATE explore / EPSILON 0.005898100000000138 / ACTION 2 / REWARD 0.0 / Q_MAX  0.016908262 / Loss  0.02132217399775982
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 1445 / STATE explore / EPSILON 0.005894800000000137 / ACTION 2 / REWARD 0.0 / Q_MAX  0.016764896 / Loss  6.266337004490197e-05
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 1446 / STATE explore / EPSILON 0.005891500000000137 / ACTION 2 / REWARD 0.0 / Q_MAX  0.016587634 / Loss  5.1646838983288035e-05
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 1447 / STATE explore / EPSILON 0.005888200000000137 / ACTION 2 / REWARD 0.0 / Q_MAX  0.016363973 / Loss  0.02065894566476345
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 1448 / STATE explore / EPSILON 0.005884900000000136 / ACTION 2 / REWARD 0.0 / Q_MAX  0.015581908 / Loss  0.020588334649801254
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 1449 / STATE explore / EPSILON 0.005881600000000136 / ACTION 2 / REWARD 0.0 / Q_MAX  0.01565633 / Loss  0.010707003064453602
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 1450 / STATE explore / EPSILON 0.005878300000000136 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0151022 / Loss  0.010549484752118587
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 1451 / STATE explore / EPSILON 0.005875000000000135 / ACTION 2 / REWARD 0.0 / Q_MAX  0.014355981 / Loss  4.319040453992784e-05
# INFO {'ale.lives': 3}
# Terminal False
# TIMESTEP 1452 / STATE explore / EPSILON 0.005871700000000135 / ACTION 2 / REWARD 0.0 / Q_MAX  0.013563364 / Loss  0.020667819306254387
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1453 / STATE explore / EPSILON 0.005868400000000135 / ACTION 2 / REWARD -1.0 / Q_MAX  0.01350783 / Loss  0.01017033215612173
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1454 / STATE explore / EPSILON 0.005865100000000134 / ACTION 2 / REWARD 0.0 / Q_MAX  0.013725589 / Loss  0.021039633080363274
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1455 / STATE explore / EPSILON 0.005861800000000134 / ACTION 2 / REWARD 0.0 / Q_MAX  0.012908746 / Loss  0.03094254992902279
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1456 / STATE explore / EPSILON 0.0058585000000001336 / ACTION 2 / REWARD 0.0 / Q_MAX  0.012357167 / Loss  3.495394776109606e-05
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1457 / STATE explore / EPSILON 0.005855200000000133 / ACTION 2 / REWARD 0.0 / Q_MAX  0.011677929 / Loss  0.031097441911697388
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1458 / STATE explore / EPSILON 0.005851900000000133 / ACTION 2 / REWARD 0.0 / Q_MAX  0.010158955 / Loss  0.01008000411093235
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1459 / STATE explore / EPSILON 0.0058486000000001325 / ACTION 2 / REWARD 0.0 / Q_MAX  0.008563307 / Loss  4.169154999544844e-05
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1460 / STATE explore / EPSILON 0.005845300000000132 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0071589956 / Loss  0.010746271349489689
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1461 / STATE explore / EPSILON 0.005842000000000132 / ACTION 2 / REWARD 0.0 / Q_MAX  0.006506328 / Loss  0.010521359741687775
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1462 / STATE explore / EPSILON 0.0058387000000001315 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0049561495 / Loss  0.031199734658002853
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1463 / STATE explore / EPSILON 0.005835400000000131 / ACTION 2 / REWARD 0.0 / Q_MAX  0.005375842 / Loss  0.02100956067442894
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1464 / STATE explore / EPSILON 0.005832100000000131 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0072378065 / Loss  0.010778873227536678
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1465 / STATE explore / EPSILON 0.00582880000000013 / ACTION 2 / REWARD 0.0 / Q_MAX  0.008893971 / Loss  0.03134983777999878
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1466 / STATE explore / EPSILON 0.00582550000000013 / ACTION 2 / REWARD 0.0 / Q_MAX  0.009674445 / Loss  2.3344597138930112e-05
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1494 / STATE explore / EPSILON 0.00573310000000012 / ACTION 2 / REWARD 0.0 / Q_MAX  0.00095374696 / Loss  0.01032828725874424
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1495 / STATE explore / EPSILON 0.00572980000000012 / ACTION 2 / REWARD 0.0 / Q_MAX  0.00021949294 / Loss  0.010332108475267887
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1496 / STATE explore / EPSILON 0.0057265000000001195 / ACTION 2 / REWARD 0.0 / Q_MAX  -0.0007350826 / Loss  0.010394824668765068
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1497 / STATE explore / EPSILON 0.005723200000000119 / ACTION 2 / REWARD 0.0 / Q_MAX  -0.0020242292 / Loss  0.010386459529399872
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1498 / STATE explore / EPSILON 0.005719900000000119 / ACTION 0 / REWARD 0.0 / Q_MAX  -0.003176513 / Loss  0.04173114150762558
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1499 / STATE explore / EPSILON 0.0057166000000001185 / ACTION 0 / REWARD 0.0 / Q_MAX  -0.0033348715 / Loss  0.010278228670358658
# INFO {'ale.lives': 2}
# Terminal False
# Now we save model
# TIMESTEP 1500 / STATE explore / EPSILON 0.005713300000000118 / ACTION 0 / REWARD 0.0 / Q_MAX  -0.003509848 / Loss  4.0697665099287406e-05
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1501 / STATE explore / EPSILON 0.005710000000000118 / ACTION 0 / REWARD 0.0 / Q_MAX  -0.0035617107 / Loss  0.031166531145572662
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1502 / STATE explore / EPSILON 0.005706700000000117 / ACTION 0 / REWARD 0.0 / Q_MAX  -0.0039573535 / Loss  0.02101980149745941
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1503 / STATE explore / EPSILON 0.005703400000000117 / ACTION 1 / REWARD 0.0 / Q_MAX  -0.0040925164 / Loss  0.010269513353705406
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1504 / STATE explore / EPSILON 0.005700100000000117 / ACTION 1 / REWARD 0.0 / Q_MAX  -0.0039160964 / Loss  0.020815862342715263
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1505 / STATE explore / EPSILON 0.005696800000000116 / ACTION 1 / REWARD 0.0 / Q_MAX  -0.00359161 / Loss  0.02066895365715027
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1506 / STATE explore / EPSILON 0.005693500000000116 / ACTION 1 / REWARD 0.0 / Q_MAX  -0.003858452 / Loss  0.03127390146255493
# INFO {'ale.lives': 2}
# Terminal False
# TIMESTEP 1507 / STATE explore / EPSILON 0.005690200000000116 / ACTION 1 / REWARD 0.0 / Q_MAX  -0.0040981984 / Loss  0.02081775665283203
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1508 / STATE explore / EPSILON 0.005686900000000115 / ACTION 2 / REWARD -1.0 / Q_MAX  -0.0037016738 / Loss  0.03173751384019852
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1509 / STATE explore / EPSILON 0.005683600000000115 / ACTION 2 / REWARD 0.0 / Q_MAX  -0.002557512 / Loss  0.010608149692416191
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1510 / STATE explore / EPSILON 0.005680300000000115 / ACTION 2 / REWARD 0.0 / Q_MAX  -0.0010992234 / Loss  0.021000953391194344
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1511 / STATE explore / EPSILON 0.005677000000000114 / ACTION 2 / REWARD 0.0 / Q_MAX  -0.00027502578 / Loss  0.010592812672257423
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1512 / STATE explore / EPSILON 0.005673700000000114 / ACTION 2 / REWARD 0.0 / Q_MAX  0.00063228374 / Loss  0.010399079881608486
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1513 / STATE explore / EPSILON 0.0056704000000001135 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0012071776 / Loss  0.020487111061811447
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1514 / STATE explore / EPSILON 0.005667100000000113 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0015310531 / Loss  0.010454189963638783
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1515 / STATE explore / EPSILON 0.005663800000000113 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0020492536 / Loss  1.1210258890059777e-05
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1516 / STATE explore / EPSILON 0.0056605000000001125 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0024336441 / Loss  0.010388825088739395
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1517 / STATE explore / EPSILON 0.005657200000000112 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0030296957 / Loss  0.020891273394227028
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1518 / STATE explore / EPSILON 0.005653900000000112 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0031349622 / Loss  0.010426443070173264
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1519 / STATE explore / EPSILON 0.0056506000000001114 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0034684802 / Loss  0.010240474715828896
# INFO {'ale.lives': 1}
# Terminal False
# TIMESTEP 1520 / STATE explore / EPSILON 0.005647300000000111 / ACTION 2 / REWARD 0.0 / Q_MAX  0.0035547 / Loss  1.0660844054655172e-05
# INFO {'ale.lives': 1}
# Terminal False
